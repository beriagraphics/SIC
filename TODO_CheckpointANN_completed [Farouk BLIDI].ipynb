# %% [markdown]
# # Introduction
# In this practical, we implement and train a feed-forward neural network (also known as an "MLP" for "multi-layer perceptron") on a dataset called "Fashion MNIST", consisting of small greyscale images of items of fashion.

# %% [markdown]
# # Learning Objectives
#
# * Understand how to use Keras Layers to build a neural network architecture
# * Understand how a model is trained and evaluated
# * Understand the concept of train/validation/test split and why it's useful

# %%
# !pip install -U -q keras
# !pip install -U -q tensorflow

# %%
from __future__ import print_function

import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# # Data
# In this practical, we use the Fashion MNIST dataset consisting of 70,000 greyscale images and their labels. The dataset is divided
#  into 60,000 training images and 10,000 test images. The idea is to train a **classifier** to identify the class value (what type of fashion item it is) given the image. We train and *tune* a model on the 60,000 training images and then evaluate how well it classifies the 10,000 test images that the model did not see during training. This task is an example of a **supervised learning** problem, where we are given both input and labels (targets) to learn from. This is in contrast to **unsupervised learning** where we only have inputs from which to learn patterns or **reinforcement learning** where an agent learns how to maximise a reward signal through interaction with its environment.

# %% [markdown]
# ![Texte alternatif…](https://res.cloudinary.com/practicaldev/image/fetch/s---fNWEeWA--/c_imagga_scale,f_auto,fl_progressive,h_420,q_auto,w_1000/https://raw.githubusercontent.com/zalandoresearch/fashion-mnist/master/doc/img/fashion-mnist-sprite.png)

# %% [markdown]
# # Train/Validation/Test Split
#
# When we build machine learning models, the goal is to build a model that will perform well on future data that we have not seen yet. We say that we want our models to be able to generalise well from whatever training data we can collect and do have available, to whatever data we will be applying them to in future. To do this, we split whatever data we have available into a training set, a validation set and a test set. The idea is that we train our model and use the performance on the validation set to make any adjustments to the model and its hyperparameters, but then we report the final accuracy on the test set. The test set (which we never train on), therefore acts as a proxy for our future data.

# %%
(train_and_validation_images, train_and_validation_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_and_validation_labels.shape
# Out:
# (60000,)

# %%
# Construct a validation set from the last 10000 images and labels from 
# train_and_validation_images and train_and_validation_labels
validation_images = train_and_validation_images[-10000:, :, :]
validation_labels = train_and_validation_labels[-10000:]

# Construct a training set from the first 50000 images and labels.
train_images = train_and_validation_images[:50000, :, :]
train_labels = train_and_validation_labels[:50000]

# %%
text_labels = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
random_index = np.random.randint(0, len(train_images))
plt.imshow(train_images[random_index], cmap='gray')
plt.colorbar()
numerical_label = train_labels[random_index]
text_description = text_labels[numerical_label]
plt.title('True Class: {} ("{}")'.format(numerical_label, text_description))

plt.gca().grid(False)

# %%
# Another view, showing 50 randomly selected images at a time
plt.figure(figsize=(20,20))
for i in range(50):
    plt.subplot(5,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 50000)
    plt.imshow(train_images[img_index], cmap=plt.cm.gray)
    plt.xlabel(text_labels[train_labels[img_index]])

# %% [markdown]
# # Preprocess

# %%
# Flatten

train_images_flatten = train_images.reshape(train_images.shape[0], 784)
validation_images_flatten = validation_images.reshape(validation_images.shape[0], 784)
test_images_flatten = test_images.reshape(test_images.shape[0], 784)

# %%
# Normalize

train_images_model = train_images_flatten/255.
validation_images_model = validation_images_flatten/255.
test_images_model = test_images_flatten/255.

# %%
# convert class vectors to binary class matrices
train_labels_categ = tf.keras.utils.to_categorical(train_labels, 10)
validation_labels_categ = tf.keras.utils.to_categorical(validation_labels, 10)
test_labels_categ = tf.keras.utils.to_categorical(test_labels, 10)

# %% [markdown]
# # Train

# %%
batch_size = 128
num_classes = 10
epochs = 40
input_dim = train_images_flatten.shape

# Create a sequential model here 
model = Sequential([
    Dense(256, input_dim=input_dim[1], activation="relu"),
    Dropout(0.2, input_shape=(256,)),
    Dense(128, activation="relu"),
    Dense(num_classes, activation="softmax")
    ], name ="Sequential_2")

model.summary()

# End Code
# Out:
# Model: "Sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(train_images_flatten, train_labels_categ,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(validation_images_flatten, validation_labels_categ))
# Out:
# Epoch 1/40
# 391/391 [==============================] - 4s 7ms/step - loss: 6.8509 - accuracy: 0.6599 - val_loss: 0.7375 - val_accuracy: 0.7256
# Epoch 2/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.8552 - accuracy: 0.7429 - val_loss: 0.5979 - val_accuracy: 0.7926
# Epoch 3/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.6410 - accuracy: 0.7886 - val_loss: 0.5903 - val_accuracy: 0.7814
# Epoch 4/40
# 391/391 [==============================] - 3s 6ms/step - loss: 0.5726 - accuracy: 0.8088 - val_loss: 0.4979 - val_accuracy: 0.8194
# Epoch 5/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5343 - accuracy: 0.8200 - val_loss: 0.4599 - val_accuracy: 0.8340
# Epoch 6/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.5020 - accuracy: 0.8295 - val_loss: 0.4293 - val_accuracy: 0.8524
# Epoch 7/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4868 - accuracy: 0.8344 - val_loss: 0.4264 - val_accuracy: 0.8533
# Epoch 8/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4805 - accuracy: 0.8389 - val_loss: 0.5271 - val_accuracy: 0.8256
# Epoch 9/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4681 - accuracy: 0.8444 - val_loss: 0.4546 - val_accuracy: 0.8546
# Epoch 10/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4685 - accuracy: 0.8441 - val_loss: 0.4417 - val_accuracy: 0.8592
# Epoch 11/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4529 - accuracy: 0.8512 - val_loss: 0.4384 - val_accuracy: 0.8669
# Epoch 12/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4545 - accuracy: 0.8500 - val_loss: 0.4430 - val_accuracy: 0.8623
# Epoch 13/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4497 - accuracy: 0.8519 - val_loss: 0.4722 - val_accuracy: 0.8539
# Epoch 14/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4444 - accuracy: 0.8560 - val_loss: 0.4695 - val_accuracy: 0.8633
# Epoch 15/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4439 - accuracy: 0.8569 - val_loss: 0.4602 - val_accuracy: 0.8556
# Epoch 16/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4380 - accuracy: 0.8564 - val_loss: 0.4763 - val_accuracy: 0.8504
# Epoch 17/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4338 - accuracy: 0.8582 - val_loss: 0.4967 - val_accuracy: 0.8589
# Epoch 18/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4333 - accuracy: 0.8570 - val_loss: 0.4857 - val_accuracy: 0.8662
# Epoch 19/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4208 - accuracy: 0.8603 - val_loss: 0.5128 - val_accuracy: 0.8519
# Epoch 20/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4317 - accuracy: 0.8631 - val_loss: 0.4947 - val_accuracy: 0.8637
# Epoch 21/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4152 - accuracy: 0.8627 - val_loss: 0.5620 - val_accuracy: 0.8398
# Epoch 22/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4138 - accuracy: 0.8650 - val_loss: 0.5021 - val_accuracy: 0.8599
# Epoch 23/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4133 - accuracy: 0.8642 - val_loss: 0.4932 - val_accuracy: 0.8733
# Epoch 24/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4140 - accuracy: 0.8654 - val_loss: 0.5287 - val_accuracy: 0.8689
# Epoch 25/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4148 - accuracy: 0.8665 - val_loss: 0.5563 - val_accuracy: 0.8569
# Epoch 26/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4174 - accuracy: 0.8678 - val_loss: 0.5519 - val_accuracy: 0.8640
# Epoch 27/40
# 391/391 [==============================] - 3s 6ms/step - loss: 0.4183 - accuracy: 0.8656 - val_loss: 0.5092 - val_accuracy: 0.8602
# Epoch 28/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4087 - accuracy: 0.8688 - val_loss: 0.5928 - val_accuracy: 0.8634
# Epoch 29/40
# 391/391 [==============================] - 3s 6ms/step - loss: 0.4243 - accuracy: 0.8678 - val_loss: 0.5702 - val_accuracy: 0.8682
# Epoch 30/40
# 391/391 [==============================] - 3s 6ms/step - loss: 0.4142 - accuracy: 0.8680 - val_loss: 0.5227 - val_accuracy: 0.8667
# Epoch 31/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4113 - accuracy: 0.8717 - val_loss: 0.5719 - val_accuracy: 0.8696
# Epoch 32/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4189 - accuracy: 0.8709 - val_loss: 0.6875 - val_accuracy: 0.8178
# Epoch 33/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4087 - accuracy: 0.8696 - val_loss: 0.5556 - val_accuracy: 0.8676
# Epoch 34/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.4107 - accuracy: 0.8715 - val_loss: 0.6460 - val_accuracy: 0.8611
# Epoch 35/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4072 - accuracy: 0.8711 - val_loss: 0.6137 - val_accuracy: 0.8684
# Epoch 36/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.3990 - accuracy: 0.8741 - val_loss: 0.6517 - val_accuracy: 0.8632
# Epoch 37/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4066 - accuracy: 0.8719 - val_loss: 0.6265 - val_accuracy: 0.8574
# Epoch 38/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4010 - accuracy: 0.8758 - val_loss: 0.6670 - val_accuracy: 0.8549
# Epoch 39/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.4073 - accuracy: 0.8730 - val_loss: 0.6883 - val_accuracy: 0.8454
# Epoch 40/40
# 391/391 [==============================] - 3s 7ms/step - loss: 0.3991 - accuracy: 0.8741 - val_loss: 0.6433 - val_accuracy: 0.8739

# %% [markdown]
# # Test

# %%
score = model.evaluate(test_images_flatten, test_labels_categ, verbose=0)
print('Test accuracy:', score[1])
# You should be able to get,at least, 88% accuracy
# Out:
# Test accuracy: 0.868399977684021

# %%
test_logits = model.predict(test_images_flatten)

# %%
test_logits
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 6.1946344e-03,
#         0.0000000e+00, 9.9379033e-01],
#        [1.3755561e-05, 2.5585408e-12, 9.8119110e-01, ..., 0.0000000e+00,
#         2.6833450e-11, 0.0000000e+00],
#        [2.4056358e-32, 1.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         2.8171362e-30, 0.0000000e+00],
#        ...,
#        [1.1083083e-11, 0.0000000e+00, 1.6496630e-25, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [3.6466452e-07, 9.9999928e-01, 4.8999207e-12, ..., 0.0000000e+00,
#         3.2542140e-21, 0.0000000e+00],
#        [7.9412656e-37, 0.0000000e+00, 0.0000000e+00, ..., 9.5725624e-04,
#         3.8324716e-32, 1.6613344e-04]], dtype=float32)

# %%
test_predictions = np.argmax(test_logits, axis=1)

# %%
test_predictions
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=int64)

# %%
len(test_predictions)
# Out:
# 10000

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 10000)
    plt.imshow(test_images[img_index], cmap=plt.cm.gray)
    
    actual_label = int(test_labels[img_index])
    predicted_label = int(test_predictions[img_index])
    
    plt.xlabel("Actual: {} ({})\n Predicted: {} ({})".format(
        actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
    ))
    
plt.tight_layout()
plt.show()

# %%
aedasdas qsd0c 0a
# Out:
#   File "<ipython-input-28-0af6fa759372>", line 1
#     aedasdas qsd0c 0a
#              ^
# SyntaxError: invalid syntax

# %%
score = model.evaluate(test_images_model, test_labels_categ, verbose=0)
print('Test accuracy:', score[1])
# You should be able to get,at least, 88% accuracy
# Out:
# Test accuracy: 0.8837000131607056
